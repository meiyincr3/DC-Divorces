# %%
import pandas as pd
import matplotlib as plt
import seaborn as sb
import numpy as np

# %%
# df = pd.read_csv("../proyecto/divorces.csv")

# %%
# Se debe leer con el separador de ";"
df = pd.read_csv("../input/divorces.csv", sep=';')
# Out:
# /var/folders/4q/ztrdsrt11lb2gp5qg6j75vh80000gn/T/ipykernel_53125/2573412603.py:2: DtypeWarning: Columns (21,23,25,37,39,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../input/divorces.csv", sep=';')

# %%
df
# Out:
#       caprov_insc  cant_insc                   parr_insc  anio_insc  \
# 0          Guayas  Guayaquil                  Rocafuerte       2023
# 1          Guayas  Guayaquil                  Rocafuerte       2023
# 2          Guayas  Guayaquil                  Rocafuerte       2023
# 3          Guayas  Guayaquil                  Rocafuerte       2023
# 4          Guayas  Guayaquil                  Rocafuerte       2023
# ...           ...        ...                         ...        ...
# 23551       Azuay     Cuenca                    El Batán       2023
# 23552      El Oro    Machala                     Machala       2023
# 23553   Pichincha      Quito                    Iñaquito       2023
# 23554  Chimborazo   Riobamba                 Lizarzaburu       2023
# 23555    Los Ríos    Mocache  Mocache, cabecera cantonal       2023
#
#          mes_insc  dia_insc fecha_insc  anio_div    mes_div  dia_div  ...  \
# 0           Enero         4   1/4/2023      2023      Enero        4  ...
# ...

# %%
df.fecha_div = pd.to_datetime(df.fecha_div)
df.fecha_mat = pd.to_datetime(df.fecha_mat)

# %%
df.fecha_div.dt.year.value_counts()
# Out:
# fecha_div
# 2023    18151
# 2022     4086
# 2021      591
# 2020      222
# 2019      166
# 2018       74
# 2017       59
# 2016       38
# 2014       27
# 2013       27
# 2015       25
# 2011       15
# 2012       13
# 2010       12
# 2009        7
# 2007        7
# 2008        6
# 2006        4
# 2002        4
# 2003        4
# 2004        3
# 2001        3
# 2005        2
# 2000        2
# 1993        2
# 1987        1
# 1999        1
# 1998        1
# 1992        1
# 1996        1
# 1982        1
# Name: count, dtype: int64

# %%
#Elimino divorcios registrados que no sean de 2023 ya que solo queremos trabajar con los 2023
# 23556 - 18151 = elimino 5405 registros
df = df.loc[df.fecha_div.dt.year ==2023,:]

# %%
df.columns
# Out:
# Index(['caprov_insc', 'cant_insc', 'parr_insc', 'anio_insc', 'mes_insc',
#        'dia_insc', 'fecha_insc', 'anio_div', 'mes_div', 'dia_div', 'fecha_div',
#        'anio_mat', 'mes_mat', 'dia_mat', 'fecha_mat', 'mcap_bie', 'dur_mat',
#        'cau_div', 'nac_1', 'cod_pais1', 'sexo_1', 'anio_nac1', 'mes_nac1',
#        'dia_nac1', 'fecha_nac1', 'edad_1', 'hijos_1', 'p_etnica1', 'niv_inst1',
#        'sabe_leer1', 'prov_hab1', 'cant_hab1', 'parr_hab1', 'area_1', 'nac_2',
#        'cod_pais2', 'sexo_2', 'anio_nac2', 'mes_nac2', 'dia_nac2',
#        'fecha_nac2', 'edad_2', 'hijos_2', 'p_etnica2', 'niv_inst2',
#        'sabe_leer2', 'prov_hab2', 'cant_hab2', 'parr_hab2', 'area_2'],
#       dtype='object')

# %%
# CASOS DE DIVORCIOS LGTB?
#(df.sexo_1 == df.sexo_2).sum()

# %%
# Queremos quedarnos con las personas que se han casado entre ecuatorianos
df = df.loc[((df.cod_pais1 == "Ecuador") & (df.cod_pais2 == "Ecuador")),:]

# %%
trashColumns = ["anio_insc","mes_insc","dia_insc","anio_div","mes_div","dia_div","anio_nac1","mes_nac1"
               ,"dia_nac1","fecha_nac1","fecha_nac2","anio_nac2","mes_nac2","dia_nac2","anio_mat","mes_mat","dia_mat","niv_inst1"
               ,"niv_inst2","sabe_leer1","sabe_leer2","p_etnica1","p_etnica2","cant_insc","parr_insc"
               ,"nac_1","nac_2", "cod_pais1","cod_pais2","fecha_insc", "caprov_insc"]
df.drop(trashColumns, axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['fecha_div', 'fecha_mat', 'mcap_bie', 'dur_mat', 'cau_div', 'sexo_1',
#        'edad_1', 'hijos_1', 'prov_hab1', 'cant_hab1', 'parr_hab1', 'area_1',
#        'sexo_2', 'edad_2', 'hijos_2', 'prov_hab2', 'cant_hab2', 'parr_hab2',
#        'area_2'],
#       dtype='object')

# %%
(df =="Sin información").sum()
# Out:
# fecha_div       0
# fecha_mat       0
# mcap_bie     1926
# dur_mat         0
# cau_div       339
# sexo_1          0
# edad_1          0
# hijos_1       593
# prov_hab1       0
# cant_hab1       0
# parr_hab1       0
# area_1          0
# sexo_2          0
# edad_2          1
# hijos_2       485
# prov_hab2       0
# cant_hab2       0
# parr_hab2       0
# area_2          0
# dtype: int64

# %%
df
# Out:
#        fecha_div  fecha_mat         mcap_bie  dur_mat  \
# 0     2023-01-04 1999-09-17               No       23
# 29    2023-01-07 2021-02-02               No        1
# 34    2023-01-19 2012-08-03               No       10
# 37    2023-04-28 2010-03-26               No       13
# 42    2023-04-28 2004-08-08               No       18
# ...          ...        ...              ...      ...
# 23547 2023-07-17 1994-12-14               No       28
# 23549 2023-05-19 2004-05-18  Sin información       19
# 23551 2023-10-25 2019-10-05               No        4
# 23553 2023-06-27 1987-01-30               No       36
# 23555 2023-01-16 1975-06-28               No       47
#
#                                                  cau_div   sexo_1 edad_1  \
# 0                  Por mutuo consentimiento vía notarial   Hombre     53
# 29                 Por mutuo consentimiento vía notarial   Hombre     22
# 34                 Por mutuo consentimiento vía judicial   Hombre     32
# ...

# %%
df.dtypes
# Out:
# fecha_div    datetime64[ns]
# fecha_mat    datetime64[ns]
# mcap_bie             object
# dur_mat               int64
# cau_div              object
# sexo_1               object
# edad_1               object
# hijos_1              object
# prov_hab1            object
# cant_hab1            object
# parr_hab1            object
# area_1               object
# sexo_2               object
# edad_2               object
# hijos_2              object
# prov_hab2            object
# cant_hab2            object
# parr_hab2            object
# area_2               object
# dtype: object

# %%
df=df.loc[(df.edad_2 != "Sin información"),:]

# %%
df.edad_1 = df.edad_1.astype("int")
df.edad_2 = df.edad_2.astype("int")
# df.hijos_2 = df.hijos_2.astype("int")
# Out:
# /var/folders/4q/ztrdsrt11lb2gp5qg6j75vh80000gn/T/ipykernel_53125/3847130954.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.edad_1 = df.edad_1.astype("int")
# /var/folders/4q/ztrdsrt11lb2gp5qg6j75vh80000gn/T/ipykernel_53125/3847130954.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.edad_2 = df.edad_2.astype("int")

# %%
(df.hijos_1 == "Sin información").sum()
# Out:
# 593

# %%
(df.hijos_2 == "Sin información").sum()
# Out:
# 484

# %%
(df.cau_div == "Sin información").sum()
# Out:
# 339

# %%
df=df.loc[(df.cau_div != "Sin información"),:]

# %%
df=df.loc[(df.hijos_1 != "Sin información"),:]

# %%
df=df.loc[(df.hijos_2 != "Sin información"),:]

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#        fecha_div  fecha_mat         mcap_bie  dur_mat  \
# 0     2023-01-04 1999-09-17               No       23
# 1     2023-01-07 2021-02-02               No        1
# 2     2023-01-19 2012-08-03               No       10
# 3     2023-04-28 2010-03-26               No       13
# 4     2023-04-28 2004-08-08               No       18
# ...          ...        ...              ...      ...
# 16675 2023-07-17 1994-12-14               No       28
# 16676 2023-05-19 2004-05-18  Sin información       19
# 16677 2023-10-25 2019-10-05               No        4
# 16678 2023-06-27 1987-01-30               No       36
# 16679 2023-01-16 1975-06-28               No       47
#
#                                                  cau_div   sexo_1  edad_1  \
# 0                  Por mutuo consentimiento vía notarial   Hombre      53
# 1                  Por mutuo consentimiento vía notarial   Hombre      22
# 2                  Por mutuo consentimiento vía judicial   Hombre      32
# ...

# %%
(df.mcap_bie == "Sin información").sum()
# Out:
# 1681

# %%
df=df.loc[(df.mcap_bie != "Sin información"),:]

# %%
(df =="Sin información").sum()
# Out:
# fecha_div    0
# fecha_mat    0
# mcap_bie     0
# dur_mat      0
# cau_div      0
# sexo_1       0
# edad_1       0
# hijos_1      0
# prov_hab1    0
# cant_hab1    0
# parr_hab1    0
# area_1       0
# sexo_2       0
# edad_2       0
# hijos_2      0
# prov_hab2    0
# cant_hab2    0
# parr_hab2    0
# area_2       0
# dtype: int64

# %%
df.shape
# Out:
# (14999, 19)

# %%
df.prov_hab1.value_counts()
# Out:
# prov_hab1
# Pichincha                         3681
# Guayas                            3440
# Manabí                            1112
# El Oro                             793
# Imbabura                           645
# Azuay                              556
# Loja                               534
# Chimborazo                         482
# Exterior                           442
# Santo Domingo de los Tsáchilas     385
# Cotopaxi                           321
# Cañar                              299
# Esmeraldas                         274
# Los Ríos                           251
# Tungurahua                         237
# Santa Elena                        231
# Morona Santiago                    218
# Carchi                             188
# Sucumbíos                          176
# Bolívar                            175
# Pastaza                            146
# Galápagos                          127
# Orellana                           108
# Napo                               104
# ...

# %%
df.prov_hab2.value_counts()
# Out:
# prov_hab2
# Pichincha                         3696
# Guayas                            3427
# Manabí                            1114
# El Oro                             804
# Imbabura                           641
# Azuay                              613
# Loja                               539
# Chimborazo                         490
# Santo Domingo de los Tsáchilas     376
# Cañar                              365
# Exterior                           333
# Cotopaxi                           314
# Los Ríos                           265
# Esmeraldas                         264
# Tungurahua                         230
# Santa Elena                        224
# Morona Santiago                    220
# Sucumbíos                          179
# Carchi                             178
# Bolívar                            178
# Pastaza                            146
# Galápagos                          123
# Orellana                           104
# Napo                               101
# ...

# %%
df.prov_hab1 = df.prov_hab1.str.replace("Exterior","Zona no Delimitada")
# Out:
# /var/folders/4q/ztrdsrt11lb2gp5qg6j75vh80000gn/T/ipykernel_53125/2546213325.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.prov_hab1 = df.prov_hab1.str.replace("Exterior","Zona no Delimitada")

# %%
df.prov_hab2 = df.prov_hab2.str.replace("Exterior","Zona no Delimitada")
# Out:
# /var/folders/4q/ztrdsrt11lb2gp5qg6j75vh80000gn/T/ipykernel_53125/357021309.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.prov_hab2 = df.prov_hab2.str.replace("Exterior","Zona no Delimitada")

# %%
df.columns
# Out:
# Index(['fecha_div', 'fecha_mat', 'mcap_bie', 'dur_mat', 'cau_div', 'sexo_1',
#        'edad_1', 'hijos_1', 'prov_hab1', 'cant_hab1', 'parr_hab1', 'area_1',
#        'sexo_2', 'edad_2', 'hijos_2', 'prov_hab2', 'cant_hab2', 'parr_hab2',
#        'area_2'],
#       dtype='object')

# %%
df.parr_hab2.value_counts()
# Out:
# parr_hab2
# Tarqui                                               1020
# Guayaquil, cabecera cantonal y capital provincial     763
# Ximena                                                688
# Centro Histórico                                      367
# Machala                                               357
#                                                      ...
# Lita                                                    1
# Ramón Campaña                                           1
# La Península                                            1
# Huertas                                                 1
# Pueblo Nuevo                                            1
# Name: count, Length: 721, dtype: int64

# %%
df.dtypes
# Out:
# fecha_div    datetime64[ns]
# fecha_mat    datetime64[ns]
# mcap_bie             object
# dur_mat               int64
# cau_div              object
# sexo_1               object
# edad_1                int64
# hijos_1              object
# prov_hab1            object
# cant_hab1            object
# parr_hab1            object
# area_1               object
# sexo_2               object
# edad_2                int64
# hijos_2              object
# prov_hab2            object
# cant_hab2            object
# parr_hab2            object
# area_2               object
# dtype: object

# %%
df.to_csv("../output/clean_divorce.csv",index=False)
